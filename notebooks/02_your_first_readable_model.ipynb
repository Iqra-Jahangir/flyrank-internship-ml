# %% [markdown]
# # Week 2 — The model is just a rule you can read
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Iqra-Jahangir/flyrank-internship-ml/blob/main/notebooks/02_your_first_readable_model.ipynb?flush_cache=true)
#
# You'll:
# 1. Write a **1-line hand rule** and rank pages with it.
# 2. Fit a **depth-2 decision tree** and `print` it — the model "learned" a readable if/else. Then compare — where does it beat your rule, and where doesn’t it?
# 3. See **why you never feed the outcome back in** — that's leakage.
#
# The payoff isn't a high score. It's: *my intuition was rough, the model found the real signal, and I can read exactly what it found.*

# %% [markdown]
# ## 0. Setup (Colab or local)

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

import pandas as pd, numpy as np
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# The label: a page is 'declining' when its recent trend is down. Simple, honest starter label.
df["is_declining_label"] = df["trend_direction"].str.lower().eq("down").astype(int)
print(df.shape[0], "pages |  declining rate:", round(df["is_declining_label"].mean(), 3))
# Out:
# 30000 pages |  declining rate: 0.542

# %% [markdown]
# ## 1. A rule you write by hand: `stale x visible`
# Intuition: a page worth reviewing is one that is **stale** (not updated in a while) **and** still **visible** (getting impressions). Rank those by how much exposure they have.

# %%
stale   = (df["days_since_last_update"] >= 180).astype(int)
visible = (df["impressions_90d"] >= 500).astype(int)
df["hand_rule_score"] = stale * visible * df["impressions_90d"]

top10 = df.sort_values("hand_rule_score", ascending=False).head(10)
top10[["impressions_90d", "days_since_last_update", "avg_position", "ctr", "trend_direction"]]
# Out:
#        impressions_90d  days_since_last_update  avg_position   ctr  \
# 16751            61678                     194          19.7  0.15
# 16514            59472                     194          24.8  0.13
# 7021             25715                     194          22.2  0.23
# 21268            13299                     193          10.5  0.49
# 11489             7812                     194          39.0  0.01
# 12045             7558                     193          17.9  0.20
# 698               4590                     194          31.0  0.00
# 5327              4556                     194          16.4  0.33
# 26810             4429                     194          25.3  0.38
# 20837             1697                     193          15.8  0.12
#
#       trend_direction
# 16751            down
# 16514            down
# 7021             down
# 21268            down
# 11489            down
# 12045            down
# 698              down
# 5327             down
# 26810            down
# 20837            down

# %% [markdown]
# We need a way to score any ranking. **Precision@K** = of the top K pages a ranking flags, what fraction are actually declining.

# %%
def precision_at_k(scores, labels, k):
    order = np.argsort(-np.asarray(scores))
    topk = np.asarray(labels)[order[:k]]
    return topk.mean()

y = df["is_declining_label"].values
for k in (20, 50):
    print(f"Hand rule  Precision@{k}: {precision_at_k(df['hand_rule_score'], y, k):.3f}")
# Out:
# Hand rule  Precision@20: 0.900
# Hand rule  Precision@50: 0.620

# %% [markdown]
# ## 2. Let a model learn the rule — then read it
# A **depth-2 decision tree** can only ask 3 yes/no questions. That constraint is the point: whatever it learns, you can read.
#
# We give it a few **pre-decision** signals — never product flags.

# %%
from sklearn.tree import DecisionTreeClassifier, export_text

features = ["content_age_days", "days_since_last_update", "impressions_90d",
            "avg_position", "ctr", "word_count"]
X = df[features].replace([np.inf, -np.inf], np.nan).fillna(0)

tree = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree.fit(X, y)

print(export_text(tree, feature_names=features))
# Out:
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0

# %% [markdown]
# That printout **is** the model — a human-readable if/else. Now rank pages by the tree's probability and score it the same way.

# %%
tree_score = tree.predict_proba(X)[:, 1]
for k in (20, 50):
    hr = precision_at_k(df["hand_rule_score"], y, k)
    tr = precision_at_k(tree_score, y, k)
    print(f"Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")
# Out:
# Precision@20:  hand rule 0.900   vs   tree 0.800
# Precision@50:  hand rule 0.620   vs   tree 0.720

# %% [markdown]
# Now read your own printout carefully — **the winner here depends on your run.** A depth-2 tree can only give four different scores (one per leaf), so the "top 50" is mostly one big block of tied pages, and different library versions break those ties differently. On some stacks the tree wins at Precision@50; on others the hand rule holds both. **Both results are real.** The stable lesson: a sharp human rule can be excellent at the very top of the list; a model's advantage — when it shows up — appears deeper, where simple rules run out of signal; and any comparison built on heavily tied scores is fragile. Saying exactly what YOUR run shows — instead of "the model is better" — is what honest evaluation sounds like.

# %% [markdown]
# ## 3. Why you can't feed the outcome back in
# Your label is `trend_direction == "down"`, and `trend_pct` is the exact percentage change that bucket is computed from — so it **is** the answer in disguise. Watch what happens if you feed it in as a feature:

# %%
X_leaky = df[features + ["trend_pct"]].replace([np.inf, -np.inf], np.nan).fillna(0)
leaky = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42).fit(X_leaky, y)
print(f"'Leaky' tree Precision@50: {precision_at_k(leaky.predict_proba(X_leaky)[:,1], y, 50):.3f}  <- looks amazing")
print(export_text(leaky, feature_names=features + ["trend_pct"]))
# Out:
# 'Leaky' tree Precision@50: 1.000  <- looks amazing
# |--- trend_pct <= -20.05
# |   |--- word_count <= 212.00
# |   |   |--- class: 1
# |   |--- word_count >  212.00
# |   |   |--- class: 1
# |--- trend_pct >  -20.05
# |   |--- trend_pct <= -19.95
# |   |   |--- class: 0
# |   |--- trend_pct >  -19.95
# |   |   |--- class: 0

# %% [markdown]
# The tree just split on `trend_pct` and nailed the label — because the label is **derived from** `trend_pct`. That's **leakage**: the feature is the answer in disguise, and it teaches you nothing.
#
# That's also why the starter data ships **only observable signals** — the product's own decision flags (health scores, "needs CTR fix", and so on) aren't included, so you can't accidentally train on them. You build from what was knowable *before* the outcome.
#
# > Rule of thumb: if a feature would only be known *because someone already made the decision you're predicting*, it leaks. Leave it out.

# %% [markdown]
# ## 4. 🔧 Your turn
# - Change `max_depth` to 3 or 4 — does Precision@50 improve? Can you still read the tree?
# - Swap in different features (drop `impressions_90d`, add `engagement_rate`). What does the tree choose to split on first?
# - **Important caveat:** we scored *in-sample* here for teaching. The real pipeline uses **client-holdout** validation (`scripts/03_train_model.py`) so a client's pages never appear in both train and test. Re-run your comparison with a train/test split and see if the gap holds.
#
# Write your experiment below.

# %%
# Your experiment here

# Task 1: Does max_depth 3/4 improve on depth 2?
for depth in (2, 3, 4):
    t = DecisionTreeClassifier(max_depth=depth, class_weight="balanced", random_state=42)
    t.fit(X, y)
    score = t.predict_proba(X)[:, 1]
    p20 = precision_at_k(score, y, 20)
    p50 = precision_at_k(score, y, 50)
    print(f"max_depth={depth}  leaves={t.get_n_leaves()}  Precision@20={p20:.3f}  Precision@50={p50:.3f}")
    print(export_text(t, feature_names=features))
    print("-" * 60)

# Takeaway: depth 2 is best on both metrics in-sample; deeper trees add
# leaves without improving ranking quality, and are harder to read.



# Task 2: Swap impressions_90d to engagement_rate
features_v2 = ["content_age_days", "days_since_last_update", "engagement_rate",
               "avg_position", "ctr", "word_count"]
X_v2 = df[features_v2].replace([np.inf, -np.inf], np.nan).fillna(0)
tree_v2 = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree_v2.fit(X_v2, y)
print(export_text(tree_v2, feature_names=features_v2))
score_v2 = tree_v2.predict_proba(X_v2)[:, 1]
for k in (20, 50):
    print(f"Precision@{k} (engagement_rate swap): {precision_at_k(score_v2, y, k):.3f}")

# Takeaway: tree doesn't even split on engagement_rate
# falls back to avg_position and content_age_days, and performs worse : impressions_90d
# carries more signal for this label than engagement_rate does.


# Task 3: Client-holdout -- single split, then stability check across seeds
from sklearn.model_selection import GroupShuffleSplit

gss = GroupShuffleSplit(n_splits=1, test_size=0.25, random_state=42)
train_idx, test_idx = next(gss.split(X, y, groups=df["client_id"]))
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y[train_idx], y[test_idx]

tree_holdout = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
tree_holdout.fit(X_train, y_train)
test_score = tree_holdout.predict_proba(X_test)[:, 1]
hand_rule_test = df.iloc[test_idx]["hand_rule_score"].values

for k in (20, 50):
    hr = precision_at_k(hand_rule_test, y_test, k)
    tr = precision_at_k(test_score, y_test, k)
    print(f"[Held-out clients] Precision@{k}:  hand rule {hr:.3f}   vs   tree {tr:.3f}")

print(export_text(tree_holdout, feature_names=features))
print(f"\nTrain clients: {df.iloc[train_idx]['client_id'].nunique()}  |  Test clients: {df.iloc[test_idx]['client_id'].nunique()}")

# Single-split takeaway: on this particular held-out split, hand rule
# ties/beats the tree , but only 8 test clients, so check stability below.

results = []
for seed in range(10):
    gss = GroupShuffleSplit(n_splits=1, test_size=0.25, random_state=seed)
    train_idx, test_idx = next(gss.split(X, y, groups=df["client_id"]))
    X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
    y_train, y_test = y[train_idx], y[test_idx]

    t = DecisionTreeClassifier(max_depth=2, class_weight="balanced", random_state=42)
    t.fit(X_train, y_train)
    test_score = t.predict_proba(X_test)[:, 1]
    hand_rule_test = df.iloc[test_idx]["hand_rule_score"].values

    row = {"seed": seed, "n_test_clients": df.iloc[test_idx]["client_id"].nunique()}
    for k in (20, 50):
        row[f"hand_rule_p{k}"] = precision_at_k(hand_rule_test, y_test, k)
        row[f"tree_p{k}"] = precision_at_k(test_score, y_test, k)
    results.append(row)

results_df = pd.DataFrame(results)
print(results_df.round(3))

print("\n--- Summary across seeds ---")
for k in (20, 50):
    hr_mean = results_df[f"hand_rule_p{k}"].mean()
    tr_mean = results_df[f"tree_p{k}"].mean()
    tree_wins = (results_df[f"tree_p{k}"] > results_df[f"hand_rule_p{k}"]).sum()
    hand_wins = (results_df[f"hand_rule_p{k}"] > results_df[f"tree_p{k}"]).sum()
    ties = (results_df[f"tree_p{k}"] == results_df[f"hand_rule_p{k}"]).sum()
    print(f"P@{k}:  mean hand_rule={hr_mean:.3f}  mean tree={tr_mean:.3f}  "
          f"(tree wins {tree_wins}/10, hand wins {hand_wins}/10, ties {ties}/10)")

# Stability-check takeaway: the single split above was one of the tree's
# weaker draws. Averaged over 10 client splits, the tree beats the hand
# rule in 7-8/10 resamples at both P@20 and P@50, the earlier tie/loss
# was noise from a small (8-client) test fold, not the typical outcome.
# Out:
# max_depth=2  leaves=4  Precision@20=0.800  Precision@50=0.720
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0
#
# ------------------------------------------------------------
# max_depth=3  leaves=8  Precision@20=0.550  Precision@50=0.680
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- impressions_90d <= 3.50
# |   |   |   |--- class: 0
# |   |   |--- impressions_90d >  3.50
# |   |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- content_age_days <= 108.50
# |   |   |   |--- class: 0
# |   |   |--- content_age_days >  108.50
# |   |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- ctr <= 0.33
# |   |   |   |--- class: 1
# |   |   |--- ctr >  0.33
# |   |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- avg_position <= 25.15
# |   |   |   |--- class: 0
# |   |   |--- avg_position >  25.15
# |   |   |   |--- class: 0
#
# ------------------------------------------------------------
# max_depth=4  leaves=16  Precision@20=0.700  Precision@50=0.660
# |--- impressions_90d <= 5.50
# |   |--- avg_position <= 0.75
# |   |   |--- impressions_90d <= 3.50
# |   |   |   |--- word_count <= 687.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  687.00
# |   |   |   |   |--- class: 0
# |   |   |--- impressions_90d >  3.50
# |   |   |   |--- content_age_days <= 237.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- content_age_days >  237.50
# |   |   |   |   |--- class: 0
# |   |--- avg_position >  0.75
# |   |   |--- content_age_days <= 108.50
# |   |   |   |--- days_since_last_update <= 14.00
# |   |   |   |   |--- class: 1
# |   |   |   |--- days_since_last_update >  14.00
# |   |   |   |   |--- class: 0
# |   |   |--- content_age_days >  108.50
# |   |   |   |--- impressions_90d <= 2.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- impressions_90d >  2.50
# |   |   |   |   |--- class: 0
# |--- impressions_90d >  5.50
# |   |--- content_age_days <= 312.50
# |   |   |--- ctr <= 0.33
# |   |   |   |--- impressions_90d <= 73.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- impressions_90d >  73.50
# |   |   |   |   |--- class: 1
# |   |   |--- ctr >  0.33
# |   |   |   |--- impressions_90d <= 24.50
# |   |   |   |   |--- class: 0
# |   |   |   |--- impressions_90d >  24.50
# |   |   |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- avg_position <= 25.15
# |   |   |   |--- impressions_90d <= 4028.50
# |   |   |   |   |--- class: 1
# |   |   |   |--- impressions_90d >  4028.50
# |   |   |   |   |--- class: 0
# |   |   |--- avg_position >  25.15
# |   |   |   |--- word_count <= 1027.00
# |   |   |   |   |--- class: 0
# |   |   |   |--- word_count >  1027.00
# |   |   |   |   |--- class: 0
#
# ------------------------------------------------------------
# |--- avg_position <= 0.55
# |   |--- avg_position <= 0.15
# |   |   |--- class: 0
# |   |--- avg_position >  0.15
# |   |   |--- class: 0
# |--- avg_position >  0.55
# |   |--- content_age_days <= 287.50
# |   |   |--- class: 1
# |   |--- content_age_days >  287.50
# |   |   |--- class: 0
#
# Precision@20 (engagement_rate swap): 0.450
# Precision@50 (engagement_rate swap): 0.560
# [Held-out clients] Precision@20:  hand rule 0.600   vs   tree 0.600
# [Held-out clients] Precision@50:  hand rule 0.500   vs   tree 0.460
# |--- impressions_90d <= 7.50
# |   |--- avg_position <= 1.65
# |   |   |--- class: 0
# |   |--- avg_position >  1.65
# |   |   |--- class: 0
# |--- impressions_90d >  7.50
# |   |--- content_age_days <= 312.50
# |   |   |--- class: 1
# |   |--- content_age_days >  312.50
# |   |   |--- class: 0
#
#
# Train clients: 24  |  Test clients: 8
#    seed  n_test_clients  hand_rule_p20  tree_p20  hand_rule_p50  tree_p50
# 0     0               8           0.70      0.75           0.52      0.66
# 1     1               8           0.60      0.65           0.56      0.52
# 2     2               8           0.60      0.70           0.54      0.62
# 3     3               8           0.70      0.75           0.54      0.70
# 4     4               8           0.45      0.70           0.46      0.60
# 5     5               8           0.60      0.65           0.56      0.54
# 6     6               8           0.80      0.65           0.70      0.66
# 7     7               8           0.50      0.40           0.40      0.44
# 8     8               8           0.65      0.80           0.58      0.72
# 9     9               8           0.65      0.85           0.50      0.84
#
# --- Summary across seeds ---
# P@20:  mean hand_rule=0.625  mean tree=0.690  (tree wins 8/10, hand wins 2/10, ties 0/10)
# P@50:  mean hand_rule=0.536  mean tree=0.630  (tree wins 7/10, hand wins 3/10, ties 0/10)

# %% [markdown]
# ### Save your work
# **Colab:** *File → Save a copy in GitHub* (your submission) and *File → Save a copy in Drive*.
#
# You now have the two core reflexes of applied ML: **discover before you model**, and **prefer a model you can read and can't fool**. That's the whole foundation the capstone builds on.
